# %%
import gvar as gv
import h5py
import pathlib
import numpy as np

# %%
RESULTS = {
    0: ()
}

# %%
ensemble = "D251"
bin_size = 2

run_id  = "test-run21"
run_dir = pathlib.Path(f"/home/ck/phd/results/c2pt/D251/D251-c2pt-fits-{run_id}")

# %%
print(ensemble)
# Out:
# D251
