# %%
import gvar as gv
import numpy as np
import pickle

from cora.momenta import *
from cora.visualise import *

# %%
# LOAD DATA
with open('/glurch/scratch/kic04594/data/misc/C101-LHPC-RATIOS-COMPARISON.pkl', 'rb') as f:
    ratios = pickle.load(f)

# %%
reg_src_ids  = [0, 1, 2, 3]
lhpc_src_ids = [0, 1, 2, 3]

# %%
# momentum index qidx = 0 corresponds to (0,0,0) (forward limit)
qmax = 8
qcol: dict[str] = momentum_index_dict(qmax)
qidx = qcol['(0, 0, 1)']

fig = plot_lhpc_comparison('pseudoscalar', ratios, qcol, qidx, reg_src_ids, lhpc_src_ids)
plt.show()
# Out:
# SOURCE ID 0
# tau         REG_err       LHPC_err
#    0        0.5035        0.4134
#    1        0.5291        0.4460
#    2        0.5536        0.4650
#    3        0.5729        0.4832
#    4        0.6101        0.5079
#    5        0.6113        0.5425
#    6        0.6067        0.5712
#    7        0.6469        0.5893
#    8        0.6580        0.6147
#    9        0.6220        0.6273
#   10        0.5813        0.5696
#   11        0.5704        0.5370
#   12        0.5377        0.5027
#   13        0.5156        0.4784
#   14        0.4954        0.4563
# SOURCE ID 1
# tau         REG_err       LHPC_err
#    0        0.4479        2.0206
#    1        0.4797        1.6882
#    2        0.5012        1.3764
#    3        0.5044        1.2044
#    4        0.4882        1.1938
#    5        0.5186        1.2401
#    6        0.5534        1.3736
#    7        0.5526        0.9542
#    8        0.5510        0.6918
#    9        0.5450        0.5889
#   10        0.5624        0.5587
#   11        0.6432        0.5403
#   12        0.7182        0.5182
#   13        0.7793        0.4817
#   14        0.7221        0.4349
# SOURCE ID 2
# tau         REG_err       LHPC_err
#    0        0.4074        0.5384
#    1        0.4377        0.5958
#    2        0.4568        0.6298
#    3        0.4596        0.6691
#    4        0.4619        0.6976
#    5        0.4715        0.7136
#    6        0.4969        0.7740
#    7        0.5031        0.8620
#    8        0.4998        0.9118
#    9        0.4856        0.8897
#   10        0.4701        0.9562
#   11        0.4519        0.9265
#   12        0.4349        0.8710
#   13        0.4054        0.8216
#   14        0.3683        0.7576
# SOURCE ID 3
# tau         REG_err       LHPC_err
#    0        0.6572        2.2623
#    1        0.6549        1.9871
#    2        0.6662        1.7268
#    3        0.6836        1.4017
#    4        0.7125        1.0253
#    5        0.7248        0.9899
#    6        0.7170        0.9056
#    7        0.6851        0.9052
#    8        0.6608        0.9778
#    9        0.6514        1.0459
#   10        0.6568        1.0358
#   11        0.6469        0.9897
#   12        0.6360        0.9627
#   13        0.6199        0.9399
#   14        0.5879        0.9056
